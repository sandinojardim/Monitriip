# %%
import pandas as pd
# set the display options to show all the rows
pd.set_option('display.max_rows', None)

# %%
ts = pd.read_csv('horarios.csv',encoding = "ISO-8859-1",sep=';')

# %%
ts.head()
# Out:
#                  cnpj                   razao_social data_autorizacao  \
# 0  34.805.903/0001-61  AMATUR AMAZÔNIA TURISMO LTDA.       20/07/2016
# 1  34.805.903/0001-61  AMATUR AMAZÔNIA TURISMO LTDA.       20/07/2016
# 2  34.805.903/0001-61  AMATUR AMAZÔNIA TURISMO LTDA.       05/10/2016
# 3  34.805.903/0001-61  AMATUR AMAZÔNIA TURISMO LTDA.       05/10/2016
# 4  34.805.903/0001-61  AMATUR AMAZÔNIA TURISMO LTDA.       05/10/2016
#
#       prefixo             descricao_linha          tipo_veiculo sentido  \
# 0  01-0002-00  MANAUS(AM) - BOA VISTA(RR)  CONVEN. C/ SANITÁRIO     ida
# 1  01-0002-00  MANAUS(AM) - BOA VISTA(RR)  CONVEN. C/ SANITÁRIO   volta
# 2  01-0002-31  MANAUS(AM) - BOA VISTA(RR)            SEMI-LEITO     ida
# 3  01-0002-31  MANAUS(AM) - BOA VISTA(RR)            SEMI-LEITO     ida
# 4  01-0002-31  MANAUS(AM) - BOA VISTA(RR)            SEMI-LEITO   volta
#
#   horario segunda_feira terca_feira  ... marco abril maio junho julho agosto  \
# 0   18:30             x         NaN  ...     x     x    x     x     x      x
# 1   19:00             x           x  ...     x     x    x     x     x      x
# 2   18:30           NaN           x  ...     x     x    x     x     x      x
# 3   20:00             x           x  ...     x     x    x     x     x      x
# 4   19:00           NaN         NaN  ...     x     x    x     x     x      x
#
#   setembro outubro novembro dezembro
# 0        x       x        x        x
# 1        x       x        x        x
# 2        x       x        x        x
# 3        x       x        x        x
# 4        x       x        x        x
#
# [5 rows x 27 columns]

# %%
pt = pd.read_csv('pontos_esquema_operacional.csv',encoding = "latin")
pt.head()
# Out:
#                  cnpj                     razao_social data_autorizacao  \
# 0  34.805.903/0001-61  AMATUR AMAZï¿½NIA TURISMO LTDA.       20/07/2016
# 1  34.805.903/0001-61  AMATUR AMAZï¿½NIA TURISMO LTDA.       20/07/2016
# 2  34.805.903/0001-61  AMATUR AMAZï¿½NIA TURISMO LTDA.       20/07/2016
# 3  34.805.903/0001-61  AMATUR AMAZï¿½NIA TURISMO LTDA.       20/07/2016
# 4  34.805.903/0001-61  AMATUR AMAZï¿½NIA TURISMO LTDA.       20/07/2016
#
#       prefixo             descricao_linha            tipo_veiculo  \
# 0  01-0002-00  MANAUS(AM) - BOA VISTA(RR)  CONVEN. C/ SANITï¿½RIO
# 1  01-0002-00  MANAUS(AM) - BOA VISTA(RR)  CONVEN. C/ SANITï¿½RIO
# 2  01-0002-00  MANAUS(AM) - BOA VISTA(RR)  CONVEN. C/ SANITï¿½RIO
# 3  01-0002-00  MANAUS(AM) - BOA VISTA(RR)  CONVEN. C/ SANITï¿½RIO
# 4  01-0002-00  MANAUS(AM) - BOA VISTA(RR)  CONVEN. C/ SANITï¿½RIO
#
#   sequencia_ponto_linha      nome_ponto_parada  \
# 0                     0  Terminal Rodoviï¿½rio
# 1                     1  Terminal Rodoviï¿½rio
# 2                     2    Auto Posto Jundiï¿½
# 3                     3      Posto Sï¿½o Vitor
# 4                     4  Terminal Rodoviï¿½rio
#
#                        municipio_uf  secao      apoio     lanche refeicao  \
# 0                 MANAUS/AM            Sim      Nï¿½o      Nï¿½o    Nï¿½o
# 1  PRESIDENTE FIGUEIREDO/AM            Sim      Nï¿½o      Nï¿½o    Nï¿½o
# 2           RORAINOPOLIS/RR          Nï¿½o  Ida/Volta  Ida/Volta    Nï¿½o
# 3           RORAINOPOLIS/RR          Nï¿½o  Ida/Volta  Ida/Volta    Nï¿½o
# 4           RORAINOPOLIS/RR            Sim      Nï¿½o  Ida/Volta    Nï¿½o
#
#   troca_de_motorista troca_de_veiculo Unnamed: 15
# 0              Nï¿½o            Nï¿½o         NaN
# 1              Nï¿½o            Nï¿½o         NaN
# 2          Ida/Volta            Nï¿½o         NaN
# 3              Nï¿½o            Nï¿½o         NaN
# 4          Ida/Volta            Nï¿½o         NaN

# %%
ln = pd.read_csv('linhas_secoes.csv',encoding = "latin")
lx = ln[ln['descricao_linha'].str.contains('BARRA DO GARCAS')]
lx['prefixo'].value_counts()
# Out:
# 02-0016-00    64
# 11-0006-41    52
# 11-0006-00    52
# 11-0006-61    52
# 11-9057-00    13
# 12-0123-61     8
# 12-0123-00     8
# 12-0639-00     4
# 12-0639-61     4
# 12-0104-00     4
# 12-0160-00     4
# 12-0261-00     3
# 12-0170-61     2
# 11-0084-00     2
# 12-0170-00     2
# 12-0159-61     1
# 12-0289-00     1
# 12-0159-00     1
# Name: prefixo, dtype: int64

# %%
ln1 = ln[ln['prefixo']=='02-0016-00']#ln[(ln['municipio_origem'] == 'GOIANIA') & (ln['municipio_destino'] == 'CUIABA')]
ln1
# Out:
#                       cnpj            razao_social  numero_tar  numero_lop  \
# 165527  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165528  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165529  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165530  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165531  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165532  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165533  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165534  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165535  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165536  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165537  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165538  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165539  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165540  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165541  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165542  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165543  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165544  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165545  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165546  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165547  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165548  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165549  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165550  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165551  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165552  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165553  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165554  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165555  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165556  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165557  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165558  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165559  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165560  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165561  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165562  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165563  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165564  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165565  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165566  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165567  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165568  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165569  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165570  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165571  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165572  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165573  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165574  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165575  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165576  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165577  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165578  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165579  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165580  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165581  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165582  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165583  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165584  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165585  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165586  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165587  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165588  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165589  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
# 165590  01.751.730/0001-97  VERDE TRANSPORTES LTDA       118.0        10.0
#
#        data_autorizacao     prefixo                   descricao_linha  \
# 165527       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165528       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165529       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165530       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165531       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165532       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165533       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165534       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165535       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165536       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165537       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165538       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165539       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165540       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165541       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165542       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165543       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165544       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165545       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165546       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165547       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165548       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165549       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165550       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165551       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165552       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165553       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165554       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165555       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165556       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165557       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165558       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165559       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165560       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165561       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165562       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165563       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165564       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165565       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165566       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165567       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165568       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165569       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165570       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165571       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165572       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165573       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165574       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165575       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165576       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165577       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165578       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165579       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165580       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165581       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165582       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165583       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165584       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165585       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165586       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165587       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165588       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165589       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
# 165590       05/04/2023  02-0016-00  MARABA(PA) - BARRA DO GARCAS(MT)
#
#                   tipo_servico           municipio_origem   uf_origem  \
# 165527  CONVEN. C/ SANITï¿½RIO                     MARABA  PA
# 165528  CONVEN. C/ SANITï¿½RIO                     MARABA  PA
# 165529  CONVEN. C/ SANITï¿½RIO                     MARABA  PA
# 165530  CONVEN. C/ SANITï¿½RIO                     MARABA  PA
# 165531  CONVEN. C/ SANITï¿½RIO                     MARABA  PA
# 165532  CONVEN. C/ SANITï¿½RIO                     MARABA  PA
# 165533  CONVEN. C/ SANITï¿½RIO                     MARABA  PA
# 165534  CONVEN. C/ SANITï¿½RIO                     MARABA  PA
# 165535  CONVEN. C/ SANITï¿½RIO       ELDORADO DOS CARAJAS  PA
# 165536  CONVEN. C/ SANITï¿½RIO       ELDORADO DOS CARAJAS  PA
# 165537  CONVEN. C/ SANITï¿½RIO       ELDORADO DOS CARAJAS  PA
# 165538  CONVEN. C/ SANITï¿½RIO       ELDORADO DOS CARAJAS  PA
# 165539  CONVEN. C/ SANITï¿½RIO       ELDORADO DOS CARAJAS  PA
# 165540  CONVEN. C/ SANITï¿½RIO       ELDORADO DOS CARAJAS  PA
# 165541  CONVEN. C/ SANITï¿½RIO       ELDORADO DOS CARAJAS  PA
# 165542  CONVEN. C/ SANITï¿½RIO       ELDORADO DOS CARAJAS  PA
# 165543  CONVEN. C/ SANITï¿½RIO                   SAPUCAIA  PA
# 165544  CONVEN. C/ SANITï¿½RIO                   SAPUCAIA  PA
# 165545  CONVEN. C/ SANITï¿½RIO                   SAPUCAIA  PA
# 165546  CONVEN. C/ SANITï¿½RIO                   SAPUCAIA  PA
# 165547  CONVEN. C/ SANITï¿½RIO                   SAPUCAIA  PA
# 165548  CONVEN. C/ SANITï¿½RIO                   SAPUCAIA  PA
# 165549  CONVEN. C/ SANITï¿½RIO                   SAPUCAIA  PA
# 165550  CONVEN. C/ SANITï¿½RIO                   SAPUCAIA  PA
# 165551  CONVEN. C/ SANITï¿½RIO                   XINGUARA  PA
# 165552  CONVEN. C/ SANITï¿½RIO                   XINGUARA  PA
# 165553  CONVEN. C/ SANITï¿½RIO                   XINGUARA  PA
# 165554  CONVEN. C/ SANITï¿½RIO                   XINGUARA  PA
# 165555  CONVEN. C/ SANITï¿½RIO                   XINGUARA  PA
# 165556  CONVEN. C/ SANITï¿½RIO                   XINGUARA  PA
# 165557  CONVEN. C/ SANITï¿½RIO                   XINGUARA  PA
# 165558  CONVEN. C/ SANITï¿½RIO                   XINGUARA  PA
# 165559  CONVEN. C/ SANITï¿½RIO                  RIO MARIA  PA
# 165560  CONVEN. C/ SANITï¿½RIO                  RIO MARIA  PA
# 165561  CONVEN. C/ SANITï¿½RIO                  RIO MARIA  PA
# 165562  CONVEN. C/ SANITï¿½RIO                  RIO MARIA  PA
# 165563  CONVEN. C/ SANITï¿½RIO                  RIO MARIA  PA
# 165564  CONVEN. C/ SANITï¿½RIO                  RIO MARIA  PA
# 165565  CONVEN. C/ SANITï¿½RIO                  RIO MARIA  PA
# 165566  CONVEN. C/ SANITï¿½RIO                  RIO MARIA  PA
# 165567  CONVEN. C/ SANITï¿½RIO                   REDENCAO  PA
# 165568  CONVEN. C/ SANITï¿½RIO                   REDENCAO  PA
# 165569  CONVEN. C/ SANITï¿½RIO                   REDENCAO  PA
# 165570  CONVEN. C/ SANITï¿½RIO                   REDENCAO  PA
# 165571  CONVEN. C/ SANITï¿½RIO                   REDENCAO  PA
# 165572  CONVEN. C/ SANITï¿½RIO                   REDENCAO  PA
# 165573  CONVEN. C/ SANITï¿½RIO                   REDENCAO  PA
# 165574  CONVEN. C/ SANITï¿½RIO                   REDENCAO  PA
# 165575  CONVEN. C/ SANITï¿½RIO  SANTA MARIA DAS BARREIRAS  PA
# 165576  CONVEN. C/ SANITï¿½RIO  SANTA MARIA DAS BARREIRAS  PA
# 165577  CONVEN. C/ SANITï¿½RIO  SANTA MARIA DAS BARREIRAS  PA
# 165578  CONVEN. C/ SANITï¿½RIO  SANTA MARIA DAS BARREIRAS  PA
# 165579  CONVEN. C/ SANITï¿½RIO  SANTA MARIA DAS BARREIRAS  PA
# 165580  CONVEN. C/ SANITï¿½RIO  SANTA MARIA DAS BARREIRAS  PA
# 165581  CONVEN. C/ SANITï¿½RIO  SANTA MARIA DAS BARREIRAS  PA
# 165582  CONVEN. C/ SANITï¿½RIO  SANTA MARIA DAS BARREIRAS  PA
# 165583  CONVEN. C/ SANITï¿½RIO        SANTANA DO ARAGUAIA  PA
# 165584  CONVEN. C/ SANITï¿½RIO        SANTANA DO ARAGUAIA  PA
# 165585  CONVEN. C/ SANITï¿½RIO        SANTANA DO ARAGUAIA  PA
# 165586  CONVEN. C/ SANITï¿½RIO        SANTANA DO ARAGUAIA  PA
# 165587  CONVEN. C/ SANITï¿½RIO        SANTANA DO ARAGUAIA  PA
# 165588  CONVEN. C/ SANITï¿½RIO        SANTANA DO ARAGUAIA  PA
# 165589  CONVEN. C/ SANITï¿½RIO        SANTANA DO ARAGUAIA  PA
# 165590  CONVEN. C/ SANITï¿½RIO        SANTANA DO ARAGUAIA  PA
#
#             municipio_destino  uf_destino  extensao_secao  \
# 165527        BARRA DO GARCAS  MT                 1554.39
# 165528  PORTO ALEGRE DO NORTE  MT                  631.49
# 165529               CONFRESA  MT                  900.59
# 165530         ALTO BOA VISTA  MT                 1027.49
# 165531  BOM JESUS DO ARAGUAIA  MT                 1081.59
# 165532   RIBEIRAO CASCALHEIRA  MT                 1178.39
# 165533               AGUA BOA  MT                 1322.39
# 165534         NOVA XAVANTINA  MT                 1410.99
# 165535  PORTO ALEGRE DO NORTE  MT                  539.55
# 165536               CONFRESA  MT                  808.65
# 165537         ALTO BOA VISTA  MT                  935.55
# 165538  BOM JESUS DO ARAGUAIA  MT                  989.65
# 165539   RIBEIRAO CASCALHEIRA  MT                 1086.45
# 165540               AGUA BOA  MT                 1230.45
# 165541         NOVA XAVANTINA  MT                 1319.05
# 165542        BARRA DO GARCAS  MT                 1462.45
# 165543  PORTO ALEGRE DO NORTE  MT                  424.22
# 165544               CONFRESA  MT                  693.32
# 165545         ALTO BOA VISTA  MT                  820.22
# 165546  BOM JESUS DO ARAGUAIA  MT                  874.32
# 165547   RIBEIRAO CASCALHEIRA  MT                  971.12
# 165548               AGUA BOA  MT                 1115.12
# 165549         NOVA XAVANTINA  MT                 1203.72
# 165550        BARRA DO GARCAS  MT                 1347.12
# 165551  PORTO ALEGRE DO NORTE  MT                  391.44
# 165552               CONFRESA  MT                  660.54
# 165553         ALTO BOA VISTA  MT                  787.44
# 165554  BOM JESUS DO ARAGUAIA  MT                  841.54
# 165555   RIBEIRAO CASCALHEIRA  MT                  938.34
# 165556               AGUA BOA  MT                 1082.34
# 165557         NOVA XAVANTINA  MT                 1170.94
# 165558        BARRA DO GARCAS  MT                 1314.34
# 165559  PORTO ALEGRE DO NORTE  MT                  365.14
# 165560               CONFRESA  MT                  634.24
# 165561         ALTO BOA VISTA  MT                  761.14
# 165562  BOM JESUS DO ARAGUAIA  MT                  815.24
# 165563   RIBEIRAO CASCALHEIRA  MT                  912.04
# 165564               AGUA BOA  MT                 1056.04
# 165565         NOVA XAVANTINA  MT                 1144.64
# 165566        BARRA DO GARCAS  MT                 1288.04
# 165567  PORTO ALEGRE DO NORTE  MT                  281.52
# 165568               CONFRESA  MT                  550.62
# 165569         ALTO BOA VISTA  MT                  677.52
# 165570  BOM JESUS DO ARAGUAIA  MT                  731.62
# 165571   RIBEIRAO CASCALHEIRA  MT                  828.42
# 165572               AGUA BOA  MT                  972.42
# 165573         NOVA XAVANTINA  MT                 1061.02
# 165574        BARRA DO GARCAS  MT                 1204.42
# 165575  PORTO ALEGRE DO NORTE  MT                  115.09
# 165576               CONFRESA  MT                  384.19
# 165577         ALTO BOA VISTA  MT                  511.09
# 165578  BOM JESUS DO ARAGUAIA  MT                  565.19
# 165579   RIBEIRAO CASCALHEIRA  MT                  661.99
# 165580               AGUA BOA  MT                  805.99
# 165581         NOVA XAVANTINA  MT                  894.59
# 165582        BARRA DO GARCAS  MT                 1037.99
# 165583  PORTO ALEGRE DO NORTE  MT                    0.10
# 165584               CONFRESA  MT                  269.20
# 165585         ALTO BOA VISTA  MT                  396.10
# 165586  BOM JESUS DO ARAGUAIA  MT                  450.20
# 165587   RIBEIRAO CASCALHEIRA  MT                  547.00
# 165588               AGUA BOA  MT                  691.00
# 165589         NOVA XAVANTINA  MT                  779.60
# 165590        BARRA DO GARCAS  MT                  923.00
#
#                    outorga_secao
# 165527  AUTORIZAï¿½ï¿½O
# 165528  AUTORIZAï¿½ï¿½O
# 165529  AUTORIZAï¿½ï¿½O
# 165530  AUTORIZAï¿½ï¿½O
# 165531  AUTORIZAï¿½ï¿½O
# 165532  AUTORIZAï¿½ï¿½O
# 165533  AUTORIZAï¿½ï¿½O
# 165534  AUTORIZAï¿½ï¿½O
# 165535  AUTORIZAï¿½ï¿½O
# 165536  AUTORIZAï¿½ï¿½O
# 165537  AUTORIZAï¿½ï¿½O
# 165538  AUTORIZAï¿½ï¿½O
# 165539  AUTORIZAï¿½ï¿½O
# 165540  AUTORIZAï¿½ï¿½O
# 165541  AUTORIZAï¿½ï¿½O
# 165542  AUTORIZAï¿½ï¿½O
# 165543  AUTORIZAï¿½ï¿½O
# 165544  AUTORIZAï¿½ï¿½O
# 165545  AUTORIZAï¿½ï¿½O
# 165546  AUTORIZAï¿½ï¿½O
# 165547  AUTORIZAï¿½ï¿½O
# 165548  AUTORIZAï¿½ï¿½O
# 165549  AUTORIZAï¿½ï¿½O
# 165550  AUTORIZAï¿½ï¿½O
# 165551  AUTORIZAï¿½ï¿½O
# 165552  AUTORIZAï¿½ï¿½O
# 165553  AUTORIZAï¿½ï¿½O
# 165554  AUTORIZAï¿½ï¿½O
# 165555  AUTORIZAï¿½ï¿½O
# 165556  AUTORIZAï¿½ï¿½O
# 165557  AUTORIZAï¿½ï¿½O
# 165558  AUTORIZAï¿½ï¿½O
# 165559  AUTORIZAï¿½ï¿½O
# 165560  AUTORIZAï¿½ï¿½O
# 165561  AUTORIZAï¿½ï¿½O
# 165562  AUTORIZAï¿½ï¿½O
# 165563  AUTORIZAï¿½ï¿½O
# 165564  AUTORIZAï¿½ï¿½O
# 165565  AUTORIZAï¿½ï¿½O
# 165566  AUTORIZAï¿½ï¿½O
# 165567  AUTORIZAï¿½ï¿½O
# 165568  AUTORIZAï¿½ï¿½O
# 165569  AUTORIZAï¿½ï¿½O
# 165570  AUTORIZAï¿½ï¿½O
# 165571  AUTORIZAï¿½ï¿½O
# 165572  AUTORIZAï¿½ï¿½O
# 165573  AUTORIZAï¿½ï¿½O
# 165574  AUTORIZAï¿½ï¿½O
# 165575  AUTORIZAï¿½ï¿½O
# 165576  AUTORIZAï¿½ï¿½O
# 165577  AUTORIZAï¿½ï¿½O
# 165578  AUTORIZAï¿½ï¿½O
# 165579  AUTORIZAï¿½ï¿½O
# 165580  AUTORIZAï¿½ï¿½O
# 165581  AUTORIZAï¿½ï¿½O
# 165582  AUTORIZAï¿½ï¿½O
# 165583  AUTORIZAï¿½ï¿½O
# 165584  AUTORIZAï¿½ï¿½O
# 165585  AUTORIZAï¿½ï¿½O
# 165586  AUTORIZAï¿½ï¿½O
# 165587  AUTORIZAï¿½ï¿½O
# 165588  AUTORIZAï¿½ï¿½O
# 165589  AUTORIZAï¿½ï¿½O
# 165590  AUTORIZAï¿½ï¿½O

# %%
vg = pd.read_csv('viagem_regular_2019.csv',encoding = "latin",sep=',')
vg[vg['nu_linha']==12012300].head(10)
# Out:
# /tmp/ipykernel_221108/2963611621.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   vg = pd.read_csv('viagem_regular_2019.csv',encoding = "latin",sep=',')
#       codigo_viagem           cnpj    placa  nu_linha  tipo_viagem  \
# 464         1800441  1751730000197  OIP1367  12012300            0
# 470         1800442  1751730000197  QBN9705  12012300            0
# 1126        1800447  1751730000197  OCT5107  12012300            0
# 3188        1800459  1751730000197  OCT5107  12012300            0
# 3189        1800460  1751730000197  OIP1367  12012300            0
# 3763        1800465  1751730000197  QBP5085  12012300            0
# 5772        1800479  1751730000197  OIP1367  12012300            0
# 6420        1800485  1751730000197  OBS2411  12012300            0
# 6421        1800486  1751730000197  QBP5085  12012300            0
# 8484        1800503  1751730000197  OCL8837  12012300            0
#
#      data_viagem_programada  hora_viagem_programada   data_inicio_viagem  \
# 464              01-07-2019                     NaN  01-07-2019 07:08:30
# 470              01-07-2019                     NaN  01-07-2019 07:01:50
# 1126             01-07-2019                     NaN  01-07-2019 12:00:01
# 3188             02-07-2019                     NaN  03-07-2019 07:02:35
# 3189             02-07-2019                     NaN  02-07-2019 06:48:49
# 3763             02-07-2019                     NaN  02-07-2019 12:30:21
# 5772             03-07-2019                     NaN  03-07-2019 06:31:14
# 6420             03-07-2019                     NaN  03-07-2019 11:45:37
# 6421             03-07-2019                     NaN  03-07-2019 11:20:57
# 8484             04-07-2019                     NaN  04-07-2019 07:27:35
#
#           data_fim_viagem  sentido_linha   latitude  longitude  pdop  \
# 464   01-07-2019 16:51:55              0 -16.652779 -49.320805   0.0
# 470   02-07-2019 16:36:32              1 -15.888750 -52.305443   0.0
# 1126  01-07-2019 21:31:13              1 -15.888703 -52.305424   0.0
# 3188  03-07-2019 16:06:22              0 -15.888639 -52.305077   0.0
# 3189  02-07-2019 16:36:34              1 -15.888618 -52.305347   0.0
# 3763  02-07-2019 19:59:26              1 -15.888560 -52.305302   0.0
# 5772  03-07-2019 16:01:11              0 -16.658825 -49.259357   0.0
# 6420  03-07-2019 19:39:13              1 -15.878819 -52.294956   0.0
# 6421  03-07-2019 21:36:16              0 -16.653233 -49.320694   0.0
# 8484  04-07-2019 16:42:19              0 -16.653259 -49.320625   0.0
#
#           numero_imei in_transbordo  codigo_viagem_transbordo
# 464   354140096671652          NÃO                       NaN
# 470   354140096670977          NÃO                       NaN
# 1126  354140096673732          NÃO                       NaN
# 3188  354140096670977          NÃO                       NaN
# 3189  354140096671199          NÃO                       NaN
# 3763  354140096671652          NÃO                       NaN
# 5772  354140096671652          NÃO                       NaN
# 6420  354140096673732          NÃO                       NaN
# 6421  354140096671678          NÃO                       NaN
# 8484  354140096670977          NÃO                       NaN

# %%
ps = pd.read_csv('venda_passagem_02_2023.csv',encoding = "latin",sep=';')
ps.head()
# Out:
#   mes_emissao_bilhete mes_viagem ponto_origem_viagem  ponto_destino_viagem  \
# 0             02/2023    02/2023        ABADIANIA/GO           ANAPOLIS/GO
# 1             02/2023    02/2023        ABADIANIA/GO  BOM JESUS DA LAPA/BA
# 2             02/2023    02/2023        ABADIANIA/GO           BRASILIA/DF
# 3             02/2023    02/2023        ABADIANIA/GO           BRASILIA/DF
# 4             02/2023    02/2023     ABELARDO LUZ/SC            ERECHIM/RS
#
#                  tipo_servico  \
# 0  Convencional com sanitário
# 1  Convencional com sanitário
# 2  Convencional com sanitário
# 3                   Executivo
# 4                   Executivo
#
#                                      tipo_gratuidade  media_valor_total  \
# 0                       Tarifa Normal - sem desconto               8.69
# 1  Tarifa Promocional - Parágrafo 3º, art. 27 do ...             206.00
# 2                       Tarifa Normal - sem desconto              13.61
# 3  Tarifa Promocional - Parágrafo 3º, art. 27 do ...              33.86
# 4                       Tarifa Normal - sem desconto              70.52
#
#    dp_valor_total  quantidade_bilhetes
# 0            1.31                   45
# 1            0.00                    1
# 2            7.65                   38
# 3            2.72                   24
# 4            0.10                    3

# %%
bg = ps[(ps['ponto_origem_viagem'] == 'BARRA DO GARCAS/MT')]
print(bg['ponto_destino_viagem'].value_counts())
# Out:
# GOIANIA/GO                     14
# CAMPO GRANDE/MS                 9
# JATAI/GO                        9
# SAO PAULO/SP                    7
# RIO VERDE/GO                    7
# BRASILIA/DF                     6
# PIRACANJUBA/GO                  6
# CACU/GO                         5
# IPORA/GO                        4
# MARINGA/PR                      4
# UBERLANDIA/MG                   3
# PRESIDENTE PRUDENTE/SP          3
# JALES/SP                        3
# CASCAVEL/PR                     3
# CAMPINAS/SP                     3
# ANDRADINA/SP                    3
# PARANAIBA/MS                    3
# SANTA FE DO SUL/SP              3
# NAVIRAI/MS                      3
# DOURADOS/MS                     3
# ANAPOLIS/GO                     3
# PALMITOS/SC                     2
# APARECIDA DO TABOADO/MS         2
# FERNANDOPOLIS/SP                2
# CAARAPO/MS                      2
# JUSSARA/GO                      2
# RIBEIRAO PRETO/SP               2
# CAMPO MOURAO/PR                 2
# ARAGARCAS/GO                    2
# TRES PASSOS/RS                  2
# ILHA SOLTEIRA/SP                2
# UBERABA/MG                      2
# SAO LUIS DE MONTES BELOS/GO     2
# PASSO FUNDO/RS                  2
# XANXERE/SC                      1
# COXIM/MS                        1
# REDENCAO/PA                     1
# ITAJA/GO                        1
# TOLEDO/PR                       1
# PALMEIRA DAS MISSOES/RS         1
# CALDAS NOVAS/GO                 1
# CAPITAO LEONIDAS MARQUES/PR     1
# PATO BRANCO/PR                  1
# REALEZA/PR                      1
# PRIMAVERA DO LESTE/MT           1
# UBIRATA/PR                      1
# VOTUPORANGA/SP                  1
# SAO JOSE DO RIO PRETO/SP        1
# Name: ponto_destino_viagem, dtype: int64

# %%
bg_vg = vg[(vg['placa'] == 'QCP1953')]#vg[vg['latitude'].between(-15.890000, -15.877281) & vg['longitude'].between(-52.256944, -52.374426)]
bg_vg.head()
# Out:
#        codigo_viagem           cnpj    placa  nu_linha  tipo_viagem  \
# 84192        3240893  3143492000162  QCP1953  11001461            0
# 84195        3240909  3143492000162  QCP1953  11001461            0
# 84196        3240917  3143492000162  QCP1953  11001461            0
# 84199        3240933  3143492000162  QCP1953  11001461            0
# 85431        3240954  3143492000162  QCP1953  11001400            0
#
#       data_viagem_programada hora_viagem_programada   data_inicio_viagem  \
# 84192             01-02-2021               17:00:00  01-02-2021 20:02:42
# 84195             02-02-2021               20:00:00  02-02-2021 23:00:01
# 84196             03-02-2021               17:00:00  03-02-2021 20:00:26
# 84199             04-02-2021               20:00:00  04-02-2021 23:01:42
# 85431             06-02-2021               20:00:00  06-02-2021 23:04:01
#
#            data_fim_viagem  sentido_linha   latitude  longitude  pdop  \
# 84192  02-02-2021 09:31:03              1   0.000000   0.000000   0.0
# 84195  03-02-2021 11:49:41              0 -10.878831 -51.637289   1.0
# 84196  04-02-2021 09:55:47              1 -10.187706 -48.306532   1.0
# 84199  05-02-2021 12:19:36              0 -10.878604 -51.637551   1.0
# 85431  07-02-2021 12:41:26              0 -10.878859 -51.637292   1.0
#
#            numero_imei in_transbordo  codigo_viagem_transbordo
# 84192  356348093248410          NÃO                       NaN
# 84195  356348093248410          NÃO                       NaN
# 84196  356348093248410          NÃO                       NaN
# 84199  356348093248410          NÃO                       NaN
# 85431  356348093248410          NÃO                       NaN

# %%
print(bg_vg['latitude'].value_counts())
# Out:
#  0.000000     1140
# -15.878957       4
# -16.659752       3
# -15.873534       3
# -15.878404       3
#               ...
# -10.878762       1
# -10.255621       1
# -12.945948       1
# -10.013596       1
# -10.879046       1
# Name: latitude, Length: 1263, dtype: int64

# %%
print(bg_vg['longitude'].value_counts())
# Out:
#  0.000000     1140
# -52.295108       4
# -49.293076       3
# -51.118932       3
# -48.028225       3
#               ...
# -51.827399       1
# -51.112211       1
# -51.112371       1
# -49.266793       1
# -51.637281       1
# Name: longitude, Length: 1258, dtype: int64

# %%
parada = pd.read_csv('parada_regular_03_2023.csv',encoding = "latin",sep=';')
parada[parada['cnpj'] == 3143492000162]
# Out:
#         codigo_viagem           cnpj    placa  motivo_parada  latitude  \
# 681483        5749900  3143492000162  QBM9165              0       0.0
# 681484        5749900  3143492000162  QBM9165              0       0.0
# 681485        5749900  3143492000162  QBM9165              4       0.0
# 681582        5749906  3143492000162  QCY7816              0       0.0
# 681583        5749906  3143492000162  QCY7816              0       0.0
#
#         longitude  pdop          data_parada      numero_imei  nu_linha  \
# 681483        0.0   0.0  01-04-2023 06:16:20  358866082545304  12014161
# 681484        0.0   0.0  01-04-2023 07:29:33  358866082545304  12014161
# 681485        0.0   0.0  01-04-2023 17:11:08  358866082545304  12014161
# 681582        0.0   0.0  31-03-2023 04:10:38  356348093369943  12014161
# 681583        0.0   0.0  31-03-2023 05:28:33  356348093369943  12014161
#
#        tipo_viagem data_viagem_progamada hora_viagem_progamada  sentido_linha
# 681483     Regular            2023-03-31      14:00:00.0000000              0
# 681484     Regular            2023-03-31      14:00:00.0000000              0
# 681485     Regular            2023-03-31      14:00:00.0000000              0
# 681582     Regular            2023-03-30      11:00:00.0000000              1
# 681583     Regular            2023-03-30      11:00:00.0000000              1

# %%
for i in range(20,23):
    print(i)
# Out:
# 20
# 21
# 22
